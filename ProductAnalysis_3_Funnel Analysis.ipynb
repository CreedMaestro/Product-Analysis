# %%
import pandas as pd # python에서의 엑셀과 같은 역할
import numpy as np # 계산을 편하게 해 주는 라이브러리
import matplotlib.pyplot as plt # 시각화
import seaborn as sns # 시각화

import matplotlib.ticker as ticker # 시각화
import matplotlib.dates as mdates # 시각화

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # _1. 데이터 불러오기

# %%
### google drive mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%time
df = pd.read_csv('/content/drive/MyDrive/ProductAnalysis/funnel_sample_final.csv')
df_base = df.copy()
# Out:
# CPU times: user 5.56 s, sys: 1.51 s, total: 7.06 s
# Wall time: 8.71 s

# %% [markdown]
# ## 1.1 data spec 확인

# %%
df_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1902435 entries, 0 to 1902434
# Data columns (total 33 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   dates                  object
#  1   hours                  int64
#  2   age_layer              object
#  3   se_inflowed            int64
#  4   se_joined              float64
#  5   se_cert_pv             float64
#  6   se_cert_done           float64
#  7   se_tax_calculation     float64
#  8   se_tax_check           float64
#  9   se_pay_pv              float64
#  10  se_is_not_target       float64
#  11  se_ref                 float64
#  12  se_ref_kt              float64
#  13  se_ref_lk              float64
#  14  se_additional_info_pv  float64
#  15  se_add_done            float64
#  16  se_edit_done           float64
#  17  se_save_done           float64
#  18  et_inflowed            object
#  19  et_joined              object
#  20  et_cert_pv             object
#  21  et_cert_done           object
#  22  et_tax_calculation     object
#  23  et_tax_check           object
#  24  et_pay_pv              object
#  25  et_is_not_target       object
#  26  et_ref                 object
#  27  et_ref_kt              object
#  28  et_ref_lk              object
#  29  et_additional_info_pv  object
#  30  et_add_done            object
#  31  et_edit_done           object
#  32  et_save_done           object
# dtypes: float64(14), int64(2), object(17)
# memory usage: 479.0+ MB

# %%
df_base.sample(5)
# Out:
#               dates  hours age_layer    se_inflowed  se_joined  se_cert_pv  \
# 1724252  2021-04-27     21   Unknown  1651062215487        NaN         NaN
# 700335   2021-04-24     11   Unknown  1650767531486        NaN         NaN
# 1422809  2021-04-26     11   Unknown  1650938474631        NaN         NaN
# 334987   2021-04-25      9   Unknown  1650848061727        NaN         NaN
# 1304440  2021-04-27     21   Unknown  1651061288310        NaN         NaN
#
#          se_cert_done  se_tax_calculation  se_tax_check  se_pay_pv  ...  \
# 1724252           NaN                 NaN           NaN        NaN  ...
# 700335            NaN                 NaN           NaN        NaN  ...
# 1422809           NaN                 NaN           NaN        NaN  ...
# 334987            NaN                 NaN           NaN        NaN  ...
# 1304440           NaN                 NaN           NaN        NaN  ...
#
#          et_tax_check  et_pay_pv  et_is_not_target  et_ref  et_ref_kt  \
# 1724252           NaN        NaN               NaN     NaN        NaN
# 700335            NaN        NaN               NaN     NaN        NaN
# 1422809           NaN        NaN               NaN     NaN        NaN
# 334987            NaN        NaN               NaN     NaN        NaN
# 1304440           NaN        NaN               NaN     NaN        NaN
#
#          et_ref_lk  et_additional_info_pv  et_add_done et_edit_done  \
# 1724252        NaN                    NaN          NaN          NaN
# 700335         NaN                    NaN          NaN          NaN
# 1422809        NaN                    NaN          NaN          NaN
# 334987         NaN                    NaN          NaN          NaN
# 1304440        NaN                    NaN          NaN          NaN
#
#         et_save_done
# 1724252          NaN
# 700335           NaN
# 1422809          NaN
# 334987           NaN
# 1304440          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# # _2. data scheme

# %% [markdown]
# | idx | column | desc | type |
# | --- | --- | --- | --- |
# | 0 | dates | 날짜 | category |
# | 1 | hours | 시각 | category |
# | 2 | age_layer | 연령대 | category |
# | ------ | ------------------------------ | ------------------------------ | ------------------------------ |
# | 3 | se_inflowed | session_유입 | 가입_이용 |
# | 4 | se_joined | session_가입 |  가입_이용 |
# | 5 | se_cert_pv | session_인증 |  가입_이용 |
# | 6 | se_cert_done | session_인증완료 | 가입_이용 |
# | 7 | se_tax_calculation | session_계산 |  가입_이용 |
# | 8 | se_tax_check | session_조회 |  가입_이용 |
# | 9 | se_pay_pv | session_결제화면 |  가입_이용 |
# | 10 | se_is_not_target | session_서비스_비대상 | 가입 _ 이용 |
# | 11 | se_ref | session_친구소개 | 친구소개 |
# | 12 | se_ref_kt | session_친구소개_시도_1 | 친구소개 |
# | 13 | se_ref_lk | session_친구소개_시도_2 | 친구소개 |
# | 14 | se_addition_info_pv | session_추가정보입력안내 | 추가정보입력 |
# | 15 | se_add_done | session_추가하기 | 추가정보입력 |
# | 16 | se_edit_done | session_수정완료 | 추가정보입력 |
# | 17 | se_save_done | session_저장완료 | 추가정보입력 |
# | ------ | ------------------------------ | ------------------------------ |------------------------------ |
# | 18 | et_inflowed | event_time_유입 | 가입_이용 |
# | 19 | et_joined | event_time_가입 | 가입_이용 |
# | 20 | et_cert_pv | event_time_인증 | 가입_이용 |
# | 21 | et_cert_done | event_time_인증완료 | 가입_이용 |
# | 22 | et_tax_calculation | event_time_계산 | 가입_이용 |
# | 23 | et_tax_check | event_time_조회 | 가입_이용 |
# | 24 | et_pay_pv | event_time_결제화면 | 가입_이용 |
# | 25 | et_is_not_target | event_time_서비스_비대상 | 가입_이용 |
# | 26 | et_ref | event_time_친구소개 | 친구소개 |
# | 27 | et_ref_kt | event_time_친구소개_시도_1 | 친구소개 |
# | 28 | et_ref_lk | event_time_친구소개_시도_2 | 친구소개 |
# | 29 | et_addition_info_pv | event_time_추가정보입력안내 | 추가정보입력 |
# | 30 | et_add_done | event_time_추가하기 | 추가정보입력 |
# | 31 | et_edit_done | event_time_수정완료 | 추가정보입력 |
# | 32 | et_save_done | event_time_저장완료 | 추가정보입력 |

# %%
df_base['basic'] = 1

# %% [markdown]
# ## 2.1 column 구분해 보기

# %% [markdown]
# ### 2.1.1 category

# %%
# 집계 기준이 되는 컬럼
# 'dates', 'hours', 'age_layer'
df_base[['dates', 'hours', 'age_layer']].head()
# Out:
#         dates  hours age_layer
# 0  2021-04-29      1   Unknown
# 1  2021-04-29      4   Unknown
# 2  2021-04-29      3   Unknown
# 3  2021-04-28     10   Unknown
# 4  2021-04-28     21   Unknown

# %%
# Python은 0부터 넘버링
df_base.columns[0:2]
# Out:
# Index(['dates', 'hours'], dtype='object')

# %%
# 마지막 넘버 + 1로 마무리
df_base.columns[0:2+1]
# Out:
# Index(['dates', 'hours', 'age_layer'], dtype='object')

# %%
# tolist() 붙여주는게 더 안전함
category = df_base.columns[0:2+1].tolist()
category
# Out:
# ['dates', 'hours', 'age_layer']

# %%
df_base[category].head()
# 첫 번째 셀 참고
# df_base[['dates', 'hours', 'age_layer']].head()
# Out:
#         dates  hours age_layer
# 0  2021-04-29      1   Unknown
# 1  2021-04-29      4   Unknown
# 2  2021-04-29      3   Unknown
# 3  2021-04-28     10   Unknown
# 4  2021-04-28     21   Unknown

# %% [markdown]
# ### 2.1.2. 가입( df_signup )

# %%
df_base.columns[3:11]
# Out:
# Index(['se_inflowed', 'se_joined', 'se_cert_pv', 'se_cert_done',
#        'se_tax_calculation', 'se_tax_check', 'se_pay_pv', 'se_is_not_target'],
#       dtype='object')

# %%
signup = df_base.columns[3:11].tolist()
signup
# Out:
# ['se_inflowed',
#  'se_joined',
#  'se_cert_pv',
#  'se_cert_done',
#  'se_tax_calculation',
#  'se_tax_check',
#  'se_pay_pv',
#  'se_is_not_target']

# %%
df_base[signup].head()
# Out:
#      se_inflowed  se_joined  se_cert_pv  se_cert_done  se_tax_calculation  \
# 0  1651164079013        NaN         NaN           NaN                 NaN
# 1  1651175470863        NaN         NaN           NaN                 NaN
# 2  1651172275521        NaN         NaN           NaN                 NaN
# 3  1651107651854        NaN         NaN           NaN                 NaN
# 4  1651149494804        NaN         NaN           NaN                 NaN
#
#    se_tax_check  se_pay_pv  se_is_not_target
# 0           NaN        NaN               NaN
# 1           NaN        NaN               NaN
# 2           NaN        NaN               NaN
# 3           NaN        NaN               NaN
# 4           NaN        NaN               NaN

# %%
signup_v1 = category + signup
signup_v1
# Out:
# ['dates',
#  'hours',
#  'age_layer',
#  'se_inflowed',
#  'se_joined',
#  'se_cert_pv',
#  'se_cert_done',
#  'se_tax_calculation',
#  'se_tax_check',
#  'se_pay_pv',
#  'se_is_not_target']

# %%
df_signup = df_base[signup_v1]
df_signup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1902435 entries, 0 to 1902434
# Data columns (total 11 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   dates               object
#  1   hours               int64
#  2   age_layer           object
#  3   se_inflowed         int64
#  4   se_joined           float64
#  5   se_cert_pv          float64
#  6   se_cert_done        float64
#  7   se_tax_calculation  float64
#  8   se_tax_check        float64
#  9   se_pay_pv           float64
#  10  se_is_not_target    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 159.7+ MB

# %% [markdown]
# ### 2.1.3. 친구소개( df_ref )

# %%
df_ref_pay = df_base[['dates', 'age_layer', 'se_pay_pv', 'se_ref', 'se_ref_kt', 'se_ref_lk']]
df_ref_pay
# Out:
#               dates age_layer  se_pay_pv  se_ref  se_ref_kt  se_ref_lk
# 0        2021-04-29   Unknown        NaN     NaN        NaN        NaN
# 1        2021-04-29   Unknown        NaN     NaN        NaN        NaN
# 2        2021-04-29   Unknown        NaN     NaN        NaN        NaN
# 3        2021-04-28   Unknown        NaN     NaN        NaN        NaN
# 4        2021-04-28   Unknown        NaN     NaN        NaN        NaN
# ...             ...       ...        ...     ...        ...        ...
# 1902430  2021-04-23   Unknown        NaN     NaN        NaN        NaN
# 1902431  2021-04-28       30s        NaN     NaN        NaN        NaN
# 1902432  2021-04-23   Unknown        NaN     NaN        NaN        NaN
# 1902433  2021-04-26   Unknown        NaN     NaN        NaN        NaN
# 1902434  2021-04-26       20s        NaN     NaN        NaN        NaN
#
# [1902435 rows x 6 columns]

# %%
df_ref_pay = df_ref_pay[df_ref_pay['se_pay_pv'].notnull()]
df_ref_pay
# Out:
#               dates age_layer     se_pay_pv  se_ref  se_ref_kt  se_ref_lk
# 2392     2021-04-25       40s  1.650849e+12     NaN        NaN        NaN
# 4586     2021-04-23       50s  1.650713e+12     NaN        NaN        NaN
# 9742     2021-04-24       40s  1.650771e+12     NaN        NaN        NaN
# 10543    2021-04-25       50s  1.650891e+12     NaN        NaN        NaN
# 11698    2021-04-28       40s  1.651144e+12     NaN        NaN        NaN
# ...             ...       ...           ...     ...        ...        ...
# 1902242  2021-04-24       40s  1.650785e+12     NaN        NaN        NaN
# 1902311  2021-04-26       40s  1.650934e+12     NaN        NaN        NaN
# 1902326  2021-04-24       50s  1.650785e+12     NaN        NaN        NaN
# 1902376  2021-04-28       50s  1.651121e+12     NaN        NaN        NaN
# 1902424  2021-04-27       40s  1.651051e+12     NaN        NaN        NaN
#
# [34550 rows x 6 columns]

# %%
df_ref_none = df_base[['dates', 'age_layer', 'se_is_not_target', 'se_ref', 'se_ref_kt', 'se_ref_lk']]
df_ref_none
# Out:
#               dates age_layer  se_is_not_target  se_ref  se_ref_kt  se_ref_lk
# 0        2021-04-29   Unknown               NaN     NaN        NaN        NaN
# 1        2021-04-29   Unknown               NaN     NaN        NaN        NaN
# 2        2021-04-29   Unknown               NaN     NaN        NaN        NaN
# 3        2021-04-28   Unknown               NaN     NaN        NaN        NaN
# 4        2021-04-28   Unknown               NaN     NaN        NaN        NaN
# ...             ...       ...               ...     ...        ...        ...
# 1902430  2021-04-23   Unknown               NaN     NaN        NaN        NaN
# 1902431  2021-04-28       30s               NaN     NaN        NaN        NaN
# 1902432  2021-04-23   Unknown               NaN     NaN        NaN        NaN
# 1902433  2021-04-26   Unknown               NaN     NaN        NaN        NaN
# 1902434  2021-04-26       20s               NaN     NaN        NaN        NaN
#
# [1902435 rows x 6 columns]

# %%
df_ref_none = df_ref_none[df_ref_none['se_is_not_target'].notnull()]
df_ref_none
# Out:
#               dates age_layer  se_is_not_target  se_ref  se_ref_kt  se_ref_lk
# 863      2021-04-23       40s      1.650707e+12     NaN        NaN        NaN
# 993      2021-04-26       20s      1.650973e+12     NaN        NaN        NaN
# 1552     2021-04-26       40s      1.650948e+12     NaN        NaN        NaN
# 2362     2021-04-28       30s      1.651121e+12     NaN        NaN        NaN
# 3138     2021-04-28       30s      1.651117e+12     NaN        NaN        NaN
# ...             ...       ...               ...     ...        ...        ...
# 1902407  2021-04-26       40s      1.650970e+12     NaN        NaN        NaN
# 1902410  2021-04-24       50s      1.650770e+12     NaN        NaN        NaN
# 1902415  2021-04-23       30s      1.650682e+12     NaN        NaN        NaN
# 1902419  2021-04-26       20s      1.650953e+12     NaN        NaN        NaN
# 1902427  2021-04-28       40s      1.651127e+12     NaN        NaN        NaN
#
# [39798 rows x 6 columns]

# %%
# df_signup ## 가입부터 결제 가능 여부 인지 funnel df
# df_ref_pay ## 결제 가능 인지한 회원의 친구 소개 funnel df
# df_ref_none ## 결제 불가능 인지한 회원의 친구 소개 funnel df

# %% [markdown]
# # _3. 전환율

# %% [markdown]
# ## 3.1. 가입 전환율

# %% [markdown]
# ### 3.1.1 데이터 준비

# %%
df_signup.sample(5)
# Out:
#               dates  hours age_layer    se_inflowed     se_joined  \
# 1580329  2021-04-26     19   Unknown  1650968223541           NaN
# 1451885  2021-04-23     21   Unknown  1650716389478           NaN
# 896444   2021-04-23     22   Unknown  1650720924936           NaN
# 1341594  2021-04-24     22   Unknown  1650806518693  1.650807e+12
# 1013549  2021-04-23     20       60s  1650714746202  1.650715e+12
#
#            se_cert_pv  se_cert_done  se_tax_calculation  se_tax_check  \
# 1580329           NaN           NaN                 NaN           NaN
# 1451885           NaN           NaN                 NaN           NaN
# 896444            NaN           NaN                 NaN           NaN
# 1341594           NaN           NaN                 NaN           NaN
# 1013549  1.650715e+12  1.650715e+12        1.650715e+12  1.650715e+12
#
#          se_pay_pv  se_is_not_target
# 1580329        NaN               NaN
# 1451885        NaN               NaN
# 896444         NaN               NaN
# 1341594        NaN               NaN
# 1013549        NaN               NaN

# %%
df_signup['basic'] = 1
df_signup.head()
# Out:
#         dates  hours age_layer    se_inflowed  se_joined  se_cert_pv  \
# 0  2021-04-29      1   Unknown  1651164079013        NaN         NaN
# 1  2021-04-29      4   Unknown  1651175470863        NaN         NaN
# 2  2021-04-29      3   Unknown  1651172275521        NaN         NaN
# 3  2021-04-28     10   Unknown  1651107651854        NaN         NaN
# 4  2021-04-28     21   Unknown  1651149494804        NaN         NaN
#
#    se_cert_done  se_tax_calculation  se_tax_check  se_pay_pv  \
# 0           NaN                 NaN           NaN        NaN
# 1           NaN                 NaN           NaN        NaN
# 2           NaN                 NaN           NaN        NaN
# 3           NaN                 NaN           NaN        NaN
# 4           NaN                 NaN           NaN        NaN
#
#    se_is_not_target  basic
# 0               NaN      1
# 1               NaN      1
# 2               NaN      1
# 3               NaN      1
# 4               NaN      1

# %%
# %%time
#df_base.groupby(['basic'])['se_inflowed', 'se_joined', 'se_cert_pv', 'se_cert_done', 'se_tax_calculation', 'se_tax_check', 'se_pay_pv', 'se_is_not_target'].agg('nunique').reset_index()

df_base.groupby(['basic'])[signup].agg('nunique').reset_index()
# Out:
# CPU times: user 1.32 s, sys: 18.1 ms, total: 1.34 s
# Wall time: 1.51 s
#    basic  se_inflowed  se_joined  se_cert_pv  se_cert_done  \
# 0      1      1899715     598172      304479        180434
#
#    se_tax_calculation  se_tax_check  se_pay_pv  se_is_not_target
# 0              148759        144110      34086             39573

# %%
#df_signup_raw = df_signup.groupby(['basic'])[df_signup.columns[2:-1]].agg('nunique').T.reset_index().rename(columns = {'index':'step', 1:'cnts'})
df_signup_raw = df_base.groupby(['basic'])[signup].agg('nunique').T.reset_index()\
                .rename(columns = {'index':'step', 1:'unique_cnt'})
df_signup_raw
# Out:
# basic                step  unique_cnt
# 0             se_inflowed     1899715
# 1               se_joined      598172
# 2              se_cert_pv      304479
# 3            se_cert_done      180434
# 4      se_tax_calculation      148759
# 5            se_tax_check      144110
# 6               se_pay_pv       34086
# 7        se_is_not_target       39573

# %%
# groupby 없이 해보기

# %%
temp_columns = df_signup.columns[2:-1].tolist()
temp_columns
# Out:
# ['age_layer',
#  'se_inflowed',
#  'se_joined',
#  'se_cert_pv',
#  'se_cert_done',
#  'se_tax_calculation',
#  'se_tax_check',
#  'se_pay_pv',
#  'se_is_not_target']

# %%
len(temp_columns)
# Out:
# 9

# %%
## basic = 1 없이 만드는 방법
cnts = []

for temp_col in temp_columns:
    temp_cnts = df_signup[temp_col].nunique()
    cnts.append(temp_cnts)

df_list = []
df_list.append(temp_columns)
df_list.append(cnts)

grouped_df = pd.DataFrame(data = df_list, index = ['step', 'cnts']).T

grouped_df
# Out:
#                  step     cnts
# 0           age_layer        6
# 1         se_inflowed  1899715
# 2           se_joined   598172
# 3          se_cert_pv   304479
# 4        se_cert_done   180434
# 5  se_tax_calculation   148759
# 6        se_tax_check   144110
# 7           se_pay_pv    34086
# 8    se_is_not_target    39573

# %% [markdown]
# ### 3.1.2. total 가입 전환율

# %%
# %%time

# 이벤트 개수로 그려보기

fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.barplot(
    data = df_signup_raw,
    x = 'step',
    y = 'unique_cnt',
)

plt.show()
# Out:
# CPU times: user 353 ms, sys: 15.3 ms, total: 368 ms
# Wall time: 563 ms

# %%
# %%time

# y축 서식

fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.barplot(
    data = df_signup_raw,
    x = 'step',
    y = 'unique_cnt',
)
ax.get_yaxis().set_major_formatter(ticker.FuncFormatter(lambda x, p: f'{x: 0,.0f}'))  #y축 1e6표시 천단위 (,)로 표현

plt.title(f'conversion_cnts', fontsize = 20)
plt.show()
# Out:
# CPU times: user 225 ms, sys: 8.02 ms, total: 233 ms
# Wall time: 270 ms

# %%
# %%time
# 누적 전환율 계산 첫번째 방법
# 분모 컬럼 생성 1. 가장 단순한 방법: 바로, 1899715를 복사하여 컬럼을 생성해 주기
df_signup_raw['first_value_1'] = 1899715
# Out:
# CPU times: user 2.59 ms, sys: 0 ns, total: 2.59 ms
# Wall time: 2.37 ms

# %%
df_signup_raw
# Out:
# basic                step  unique_cnt  first_value_1
# 0             se_inflowed     1899715        1899715
# 1               se_joined      598172        1899715
# 2              se_cert_pv      304479        1899715
# 3            se_cert_done      180434        1899715
# 4      se_tax_calculation      148759        1899715
# 5            se_tax_check      144110        1899715
# 6               se_pay_pv       34086        1899715
# 7        se_is_not_target       39573        1899715

# %%
df_signup_raw['stacked_conversion_1'] = df_signup_raw['unique_cnt']/df_signup_raw['first_value_1']
df_signup_raw
# Out:
# basic                step  unique_cnt  first_value_1  stacked_conversion_1
# 0             se_inflowed     1899715        1899715              1.000000
# 1               se_joined      598172        1899715              0.314875
# 2              se_cert_pv      304479        1899715              0.160276
# 3            se_cert_done      180434        1899715              0.094980
# 4      se_tax_calculation      148759        1899715              0.078306
# 5            se_tax_check      144110        1899715              0.075859
# 6               se_pay_pv       34086        1899715              0.017943
# 7        se_is_not_target       39573        1899715              0.020831

# %%
# %%time
# 누적 전환율 계산 두번째 방법
# 분모 컬럼 생성 2. event log 집계 수 중, 가장 큰 값으로
# 누적 전환율이기에 분모로 들어갈 수는 당연히 가장 큰 수 일것이라는 ( 합리적인 ) 기대 == 전환율은 1을 넘어갈 수 없을 것이라는 기대

df_signup_raw['basic'] = 1
df_signup_raw['first_value_2'] = df_signup_raw.groupby(['basic'])['unique_cnt'].transform('max')
# Out:
# CPU times: user 7.04 ms, sys: 86 µs, total: 7.12 ms
# Wall time: 42.3 ms

# %%
df_signup_raw
# Out:
# basic                step     cnts  first_value_1  stacked_conversion_1  \
# 0               age_layer        6        1899715              0.000003
# 1             se_inflowed  1899715        1899715              1.000000
# 2               se_joined   598172        1899715              0.314875
# 3              se_cert_pv   304479        1899715              0.160276
# 4            se_cert_done   180434        1899715              0.094980
# 5      se_tax_calculation   148759        1899715              0.078306
# 6            se_tax_check   144110        1899715              0.075859
# 7               se_pay_pv    34086        1899715              0.017943
# 8        se_is_not_target    39573        1899715              0.020831
#
# basic  basic  first_value_2
# 0          1        1899715
# 1          1        1899715
# 2          1        1899715
# 3          1        1899715
# 4          1        1899715
# 5          1        1899715
# 6          1        1899715
# 7          1        1899715
# 8          1        1899715

# %%
# %%time
# 누적 전환율 계산 3번째 방법
# 분모 컬럼 생성 3. 위치로 찾기: 행렬 원소 위치처럼( 0, 0 )에서 시작
temp_value = df_signup_raw.iloc[0, 1]
temp_value
# Out:
# CPU times: user 0 ns, sys: 310 µs, total: 310 µs
# Wall time: 321 µs
# 1899715

# %%
first_value = df_signup_raw.iloc[0, 1]
df_signup_raw['first_value_3'] = first_value
df_signup_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   step                  8 non-null      object
#  1   unique_cnt            8 non-null      int64
#  2   first_value_1         8 non-null      int64
#  3   stacked_conversion_1  8 non-null      float64
#  4   basic                 8 non-null      int64
#  5   first_value_2         8 non-null      int64
#  6   first_value_3         8 non-null      int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 576.0+ bytes

# %%
df_signup_raw ## 누적 전환율 3가지 방법 모두 추출되었는지 확인
# Out:
# basic                step  unique_cnt  first_value_1  stacked_conversion_1  \
# 0             se_inflowed     1899715        1899715              1.000000
# 1               se_joined      598172        1899715              0.314875
# 2              se_cert_pv      304479        1899715              0.160276
# 3            se_cert_done      180434        1899715              0.094980
# 4      se_tax_calculation      148759        1899715              0.078306
# 5            se_tax_check      144110        1899715              0.075859
# 6               se_pay_pv       34086        1899715              0.017943
# 7        se_is_not_target       39573        1899715              0.020831
#
# basic  basic  first_value_2  first_value_3
# 0          1        1899715        1899715
# 1          1        1899715        1899715
# 2          1        1899715        1899715
# 3          1        1899715        1899715
# 4          1        1899715        1899715
# 5          1        1899715        1899715
# 6          1        1899715        1899715
# 7          1        1899715        1899715

# %%
# %%time
# 누적전환율 시각화
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.barplot(
    data = df_signup_raw,
    x = 'step',
    y = 'stacked_conversion_1',
)

plt.axhline(1/3, color = 'darkred', linestyle ='--', linewidth = 0.5)
plt.axhline((1/3) * (1/2), color = 'darkred', linestyle ='--', linewidth = 0.5)
plt.show()
# Out:
# CPU times: user 320 ms, sys: 67.4 ms, total: 387 ms
# Wall time: 408 ms

# %%
# %%time
# 직전 전환율 계산
df_signup_raw['previous_step'] = df_signup_raw['unique_cnt'].shift(1)  #'unique_cnt'컬럼의 값을 1행씩 밀어서 삽입
df_signup_raw[['step', 'unique_cnt', 'stacked_conversion_1', 'first_value_1', 'previous_step']]
# Out:
# CPU times: user 3.33 ms, sys: 0 ns, total: 3.33 ms
# Wall time: 8.94 ms
# basic                step  unique_cnt  stacked_conversion_1  first_value_1  \
# 0             se_inflowed     1899715              1.000000        1899715
# 1               se_joined      598172              0.314875        1899715
# 2              se_cert_pv      304479              0.160276        1899715
# 3            se_cert_done      180434              0.094980        1899715
# 4      se_tax_calculation      148759              0.078306        1899715
# 5            se_tax_check      144110              0.075859        1899715
# 6               se_pay_pv       34086              0.017943        1899715
# 7        se_is_not_target       39573              0.020831        1899715
#
# basic  previous_step
# 0                NaN
# 1          1899715.0
# 2           598172.0
# 3           304479.0
# 4           180434.0
# 5           148759.0
# 6           144110.0
# 7            34086.0

# %%
df_signup_raw['previous_conversion'] = df_signup_raw['unique_cnt']/df_signup_raw['previous_step']
df_signup_raw
# Out:
# basic                step  unique_cnt  first_value_1  stacked_conversion_1  \
# 0             se_inflowed     1899715        1899715              1.000000
# 1               se_joined      598172        1899715              0.314875
# 2              se_cert_pv      304479        1899715              0.160276
# 3            se_cert_done      180434        1899715              0.094980
# 4      se_tax_calculation      148759        1899715              0.078306
# 5            se_tax_check      144110        1899715              0.075859
# 6               se_pay_pv       34086        1899715              0.017943
# 7        se_is_not_target       39573        1899715              0.020831
#
# basic  basic  first_value_2  first_value_3  previous_step  previous_conversion
# 0          1        1899715        1899715            NaN                  NaN
# 1          1        1899715        1899715      1899715.0             0.314875
# 2          1        1899715        1899715       598172.0             0.509016
# 3          1        1899715        1899715       304479.0             0.592599
# 4          1        1899715        1899715       180434.0             0.824451
# 5          1        1899715        1899715       148759.0             0.968748
# 6          1        1899715        1899715       144110.0             0.236528
# 7          1        1899715        1899715        34086.0             1.160975

# %%
df_signup_raw.drop(['first_value_1', 'first_value_2', 'first_value_3'], axis = 1, inplace = True)

# %%
df_signup_raw['previous_conversion'] = df_signup_raw['unique_cnt']/df_signup_raw['previous_step']
df_signup_raw
# Out:
# basic                step  unique_cnt  stacked_conversion_1  basic  \
# 0             se_inflowed     1899715              1.000000      1
# 1               se_joined      598172              0.314875      1
# 2              se_cert_pv      304479              0.160276      1
# 3            se_cert_done      180434              0.094980      1
# 4      se_tax_calculation      148759              0.078306      1
# 5            se_tax_check      144110              0.075859      1
# 6               se_pay_pv       34086              0.017943      1
# 7        se_is_not_target       39573              0.020831      1
#
# basic  previous_step  previous_conversion
# 0                NaN                  NaN
# 1          1899715.0             0.314875
# 2           598172.0             0.509016
# 3           304479.0             0.592599
# 4           180434.0             0.824451
# 5           148759.0             0.968748
# 6           144110.0             0.236528
# 7            34086.0             1.160975

# %%
# %%time

fig, ax = plt.subplots(nrows = 2, ncols = 1, figsize = (18,12))

#fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.lineplot(
    data = df_signup_raw.iloc[1:, :],
    x = 'step',
    y = 'stacked_conversion_1',
    marker = 'o',
    ax = ax[0]
).set_title('stacked_conversion', fontsize = 20)
plt.ylim([0,1])
#plt.axhline(1/3, color = 'darkred', linestyle ='--', linewidth = 0.5)
#plt.axhline((1/3) * (1/2), color = 'darkred', linestyle ='--', linewidth = 0.5)
#plt.show()

sns.lineplot(
      data = df_signup_raw,
      x = 'step',
      y = 'previous_conversion',
      marker = 'o',
      ax = ax[1]
).set_title('previous_conversion', fontsize = 20)

plt.show()
# Out:
# CPU times: user 554 ms, sys: 7.74 ms, total: 561 ms
# Wall time: 674 ms

# %% [markdown]
# ### 3.1.3. 가입전환율 드릴다운

# %%
# %%time
df_base.groupby(['basic', 'age_layer'])[df_base.columns[3:10].tolist()].agg('nunique').reset_index()
# Out:
# CPU times: user 1.58 s, sys: 163 ms, total: 1.74 s
# Wall time: 1.74 s
#    basic age_layer  se_inflowed  se_joined  se_cert_pv  se_cert_done  \
# 0      1       20s       109880      97104       59990         52526
# 1      1       30s        91655      77979       60197         52864
# 2      1       40s       106767      83084       69152         58306
# 3      1       50s        47311      26144       18445         13504
# 4      1       60s        12017       6196        4804          3147
# 5      1   Unknown      1532657     308035       92206           314
#
#    se_tax_calculation  se_tax_check  se_pay_pv
# 0               42020         39948       9806
# 1               43915         42988      10385
# 2               48946         47815      10610
# 3               11108         10706       2630
# 4                2687          2569        638
# 5                 269           264         68

# %%
# %%time
df_base.groupby(['basic', 'age_layer'])[df_base.columns[3:10].tolist()].agg('nunique').reset_index().T
# Out:
# CPU times: user 1.6 s, sys: 38.2 ms, total: 1.64 s
# Wall time: 1.63 s
#                          0      1       2      3      4        5
# basic                    1      1       1      1      1        1
# age_layer              20s    30s     40s    50s    60s  Unknown
# se_inflowed         109880  91655  106767  47311  12017  1532657
# se_joined            97104  77979   83084  26144   6196   308035
# se_cert_pv           59990  60197   69152  18445   4804    92206
# se_cert_done         52526  52864   58306  13504   3147      314
# se_tax_calculation   42020  43915   48946  11108   2687      269
# se_tax_check         39948  42988   47815  10706   2569      264
# se_pay_pv             9806  10385   10610   2630    638       68

# %%
# %%time
df_base.groupby(['basic', 'age_layer'])[df_base.columns[3:10].tolist()].agg('nunique').reset_index().T[1:]
# Out:
# CPU times: user 1.61 s, sys: 20.2 ms, total: 1.63 s
# Wall time: 1.63 s
#                          0      1       2      3      4        5
# age_layer              20s    30s     40s    50s    60s  Unknown
# se_inflowed         109880  91655  106767  47311  12017  1532657
# se_joined            97104  77979   83084  26144   6196   308035
# se_cert_pv           59990  60197   69152  18445   4804    92206
# se_cert_done         52526  52864   58306  13504   3147      314
# se_tax_calculation   42020  43915   48946  11108   2687      269
# se_tax_check         39948  42988   47815  10706   2569      264
# se_pay_pv             9806  10385   10610   2630    638       68

# %%
# %%time
df_signup_age = df_base.groupby(['basic', 'age_layer'])[df_base.columns[3:10].tolist()].agg('nunique').reset_index()#.T[1:].reset_index()
df_signup_age
# Out:
# CPU times: user 1.63 s, sys: 16.5 ms, total: 1.65 s
# Wall time: 1.65 s
#    basic age_layer  se_inflowed  se_joined  se_cert_pv  se_cert_done  \
# 0      1       20s       109880      97104       59990         52526
# 1      1       30s        91655      77979       60197         52864
# 2      1       40s       106767      83084       69152         58306
# 3      1       50s        47311      26144       18445         13504
# 4      1       60s        12017       6196        4804          3147
# 5      1   Unknown      1532657     308035       92206           314
#
#    se_tax_calculation  se_tax_check  se_pay_pv
# 0               42020         39948       9806
# 1               43915         42988      10385
# 2               48946         47815      10610
# 3               11108         10706       2630
# 4                2687          2569        638
# 5                 269           264         68

# %%
df_signup_age
# Out:
#    basic age_layer  se_inflowed  se_joined  se_cert_pv  se_cert_done  \
# 0      1       20s       109880      97104       59990         52526
# 1      1       30s        91655      77979       60197         52864
# 2      1       40s       106767      83084       69152         58306
# 3      1       50s        47311      26144       18445         13504
# 4      1       60s        12017       6196        4804          3147
# 5      1   Unknown      1532657     308035       92206           314
#
#    se_tax_calculation  se_tax_check  se_pay_pv
# 0               42020         39948       9806
# 1               43915         42988      10385
# 2               48946         47815      10610
# 3               11108         10706       2630
# 4                2687          2569        638
# 5                 269           264         68

# %%
df_signup_age.iloc[:-1, 1:]
# Out:
#   age_layer  se_inflowed  se_joined  se_cert_pv  se_cert_done  \
# 0       20s       109880      97104       59990         52526
# 1       30s        91655      77979       60197         52864
# 2       40s       106767      83084       69152         58306
# 3       50s        47311      26144       18445         13504
# 4       60s        12017       6196        4804          3147
#
#    se_tax_calculation  se_tax_check  se_pay_pv
# 0               42020         39948       9806
# 1               43915         42988      10385
# 2               48946         47815      10610
# 3               11108         10706       2630
# 4                2687          2569        638

# %%
df_signup_age.melt?

# %%
df_signup_age.iloc[:-1, 1:].columns[1:].tolist()
# Out:
# ['se_inflowed',
#  'se_joined',
#  'se_cert_pv',
#  'se_cert_done',
#  'se_tax_calculation',
#  'se_tax_check',
#  'se_pay_pv']

# %%
df_signup_age_v1 = df_signup_age.iloc[:-1, 1:].melt(
    id_vars = 'age_layer',
    value_vars = df_signup_age.iloc[:-1, 1:].columns[1:],
    # value_vars = ['se_inflowed', 'se_joined', 'se_cert_pv', 'se_cert_done', 'se_tax_calculation', 'se_tax_check', 'se_pay_pv']
    var_name = 'step',
    value_name = 'cnts',
)

df_signup_age_v1
# Out:
#    age_layer                step    cnts
# 0        20s         se_inflowed  109880
# 1        30s         se_inflowed   91655
# 2        40s         se_inflowed  106767
# 3        50s         se_inflowed   47311
# 4        60s         se_inflowed   12017
# 5        20s           se_joined   97104
# 6        30s           se_joined   77979
# 7        40s           se_joined   83084
# 8        50s           se_joined   26144
# 9        60s           se_joined    6196
# 10       20s          se_cert_pv   59990
# 11       30s          se_cert_pv   60197
# 12       40s          se_cert_pv   69152
# 13       50s          se_cert_pv   18445
# 14       60s          se_cert_pv    4804
# 15       20s        se_cert_done   52526
# 16       30s        se_cert_done   52864
# 17       40s        se_cert_done   58306
# 18       50s        se_cert_done   13504
# 19       60s        se_cert_done    3147
# 20       20s  se_tax_calculation   42020
# 21       30s  se_tax_calculation   43915
# 22       40s  se_tax_calculation   48946
# 23       50s  se_tax_calculation   11108
# 24       60s  se_tax_calculation    2687
# 25       20s        se_tax_check   39948
# 26       30s        se_tax_check   42988
# 27       40s        se_tax_check   47815
# 28       50s        se_tax_check   10706
# 29       60s        se_tax_check    2569
# 30       20s           se_pay_pv    9806
# 31       30s           se_pay_pv   10385
# 32       40s           se_pay_pv   10610
# 33       50s           se_pay_pv    2630
# 34       60s           se_pay_pv     638

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.barplot(
    data = df_signup_age_v1,
    x = 'step',
    y = 'cnts',
    hue = 'age_layer'
)

plt.show()
# Out:
# CPU times: user 353 ms, sys: 4.6 ms, total: 358 ms
# Wall time: 371 ms

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.lineplot(
    data = df_signup_age_v1,
    x = 'step',
    y = 'cnts',
    hue = 'age_layer',
    marker = 'o'
)

plt.show()
# Out:
# CPU times: user 315 ms, sys: 23.3 ms, total: 338 ms
# Wall time: 329 ms

# %%
# %%time
temp_df_20 = df_signup_age_v1[df_signup_age_v1['age_layer'] == '20s']
temp_df_20['conversion_raw'] = temp_df_20['cnts'].shift(1)
temp_df_20['conversion'] = temp_df_20['cnts']/temp_df_20['conversion_raw']
temp_df_20
# Out:
# CPU times: user 3.36 ms, sys: 0 ns, total: 3.36 ms
# Wall time: 3.22 ms
#    age_layer                step    cnts  conversion_raw  conversion
# 0        20s         se_inflowed  109880             NaN         NaN
# 5        20s           se_joined   97104        109880.0    0.883728
# 10       20s          se_cert_pv   59990         97104.0    0.617791
# 15       20s        se_cert_done   52526         59990.0    0.875579
# 20       20s  se_tax_calculation   42020         52526.0    0.799985
# 25       20s        se_tax_check   39948         42020.0    0.950690
# 30       20s           se_pay_pv    9806         39948.0    0.245469

# %%
temp_df_20
# Out:
#    age_layer                step    cnts  conversion_raw  conversion
# 0        20s         se_inflowed  109880             NaN         NaN
# 5        20s           se_joined   97104        109880.0    0.883728
# 10       20s          se_cert_pv   59990         97104.0    0.617791
# 15       20s        se_cert_done   52526         59990.0    0.875579
# 20       20s  se_tax_calculation   42020         52526.0    0.799985
# 25       20s        se_tax_check   39948         42020.0    0.950690
# 30       20s           se_pay_pv    9806         39948.0    0.245469

# %%
# %%time

df_conversion = pd.DataFrame()

for temp_age in sorted(df_signup_age_v1['age_layer'].unique()):
    temp_df = df_signup_age_v1[df_signup_age_v1['age_layer'] == temp_age]
    temp_df['conversion_raw'] = temp_df['cnts'].shift(1)
    temp_df['conversion'] = temp_df['cnts']/temp_df['conversion_raw']
    first_value = temp_df.iloc[0, 2]
    temp_df['stacked_conversion'] = temp_df['cnts']/first_value

    df_conversion = pd.concat([df_conversion, temp_df], axis = 0, ignore_index = True)
# Out:
# CPU times: user 23.9 ms, sys: 101 µs, total: 24 ms
# Wall time: 21.3 ms

# %%
df_conversion
# Out:
#    age_layer                step    cnts  conversion_raw  conversion  \
# 0        20s         se_inflowed  109880             NaN         NaN
# 1        20s           se_joined   97104        109880.0    0.883728
# 2        20s          se_cert_pv   59990         97104.0    0.617791
# 3        20s        se_cert_done   52526         59990.0    0.875579
# 4        20s  se_tax_calculation   42020         52526.0    0.799985
# 5        20s        se_tax_check   39948         42020.0    0.950690
# 6        20s           se_pay_pv    9806         39948.0    0.245469
# 7        30s         se_inflowed   91655             NaN         NaN
# 8        30s           se_joined   77979         91655.0    0.850788
# 9        30s          se_cert_pv   60197         77979.0    0.771964
# 10       30s        se_cert_done   52864         60197.0    0.878183
# 11       30s  se_tax_calculation   43915         52864.0    0.830717
# 12       30s        se_tax_check   42988         43915.0    0.978891
# 13       30s           se_pay_pv   10385         42988.0    0.241579
# 14       40s         se_inflowed  106767             NaN         NaN
# 15       40s           se_joined   83084        106767.0    0.778181
# 16       40s          se_cert_pv   69152         83084.0    0.832314
# 17       40s        se_cert_done   58306         69152.0    0.843157
# 18       40s  se_tax_calculation   48946         58306.0    0.839468
# 19       40s        se_tax_check   47815         48946.0    0.976893
# 20       40s           se_pay_pv   10610         47815.0    0.221897
# 21       50s         se_inflowed   47311             NaN         NaN
# 22       50s           se_joined   26144         47311.0    0.552599
# 23       50s          se_cert_pv   18445         26144.0    0.705516
# 24       50s        se_cert_done   13504         18445.0    0.732123
# 25       50s  se_tax_calculation   11108         13504.0    0.822571
# 26       50s        se_tax_check   10706         11108.0    0.963810
# 27       50s           se_pay_pv    2630         10706.0    0.245657
# 28       60s         se_inflowed   12017             NaN         NaN
# 29       60s           se_joined    6196         12017.0    0.515603
# 30       60s          se_cert_pv    4804          6196.0    0.775339
# 31       60s        se_cert_done    3147          4804.0    0.655079
# 32       60s  se_tax_calculation    2687          3147.0    0.853829
# 33       60s        se_tax_check    2569          2687.0    0.956085
# 34       60s           se_pay_pv     638          2569.0    0.248346
#
#     stacked_conversion
# 0             1.000000
# 1             0.883728
# 2             0.545959
# 3             0.478031
# 4             0.382417
# 5             0.363560
# 6             0.089243
# 7             1.000000
# 8             0.850788
# 9             0.656778
# 10            0.576772
# 11            0.479134
# 12            0.469020
# 13            0.113305
# 14            1.000000
# 15            0.778181
# 16            0.647691
# 17            0.546105
# 18            0.458438
# 19            0.447844
# 20            0.099375
# 21            1.000000
# 22            0.552599
# 23            0.389867
# 24            0.285430
# 25            0.234787
# 26            0.226290
# 27            0.055590
# 28            1.000000
# 29            0.515603
# 30            0.399767
# 31            0.261879
# 32            0.223600
# 33            0.213780
# 34            0.053091

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.lineplot(
    data = df_conversion,
    x = 'step',
    y = 'stacked_conversion',
    hue = 'age_layer',
    marker = 'o'
)

plt.show()
# Out:
# CPU times: user 284 ms, sys: 8.27 ms, total: 292 ms
# Wall time: 295 ms

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.lineplot(
    data = df_conversion,
    x = 'step',
    y = 'conversion',
    hue = 'age_layer',
    marker = 'o'
)

plt.show()
# Out:
# CPU times: user 438 ms, sys: 10.9 ms, total: 449 ms
# Wall time: 601 ms

# %% [markdown]
# ## 3.2. 친구소개

# %% [markdown]
# ### 3.2.1. 데이터 준비

# %%
df_ref_pay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34550 entries, 2392 to 1902424
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   dates      34550 non-null  object
#  1   age_layer  34550 non-null  object
#  2   se_pay_pv  34550 non-null  float64
#  3   se_ref     1220 non-null   float64
#  4   se_ref_kt  926 non-null    float64
#  5   se_ref_lk  2 non-null      float64
# dtypes: float64(4), object(2)
# memory usage: 1.8+ MB

# %%
df_ref_none.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39798 entries, 863 to 1902427
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   dates             39798 non-null  object
#  1   age_layer         39798 non-null  object
#  2   se_is_not_target  39798 non-null  float64
#  3   se_ref            1083 non-null   float64
#  4   se_ref_kt         647 non-null    float64
#  5   se_ref_lk         1 non-null      float64
# dtypes: float64(4), object(2)
# memory usage: 2.1+ MB

# %%
df_ref_pay.head()
# Out:
#             dates age_layer     se_pay_pv  se_ref  se_ref_kt  se_ref_lk
# 2392   2021-04-25       40s  1.650849e+12     NaN        NaN        NaN
# 4586   2021-04-23       50s  1.650713e+12     NaN        NaN        NaN
# 9742   2021-04-24       40s  1.650771e+12     NaN        NaN        NaN
# 10543  2021-04-25       50s  1.650891e+12     NaN        NaN        NaN
# 11698  2021-04-28       40s  1.651144e+12     NaN        NaN        NaN

# %%
df_ref_none.head()
# Out:
#            dates age_layer  se_is_not_target  se_ref  se_ref_kt  se_ref_lk
# 863   2021-04-23       40s      1.650707e+12     NaN        NaN        NaN
# 993   2021-04-26       20s      1.650973e+12     NaN        NaN        NaN
# 1552  2021-04-26       40s      1.650948e+12     NaN        NaN        NaN
# 2362  2021-04-28       30s      1.651121e+12     NaN        NaN        NaN
# 3138  2021-04-28       30s      1.651117e+12     NaN        NaN        NaN

# %%
df_ref_pay = df_ref_pay.groupby(['dates', 'age_layer'])[df_ref_pay.columns[2:]].agg('nunique').reset_index()
df_ref_none = df_ref_none.groupby(['dates', 'age_layer'])[df_ref_none.columns[2:]].agg('nunique').reset_index()

# %%
df_ref_pay.head(2)
# Out:
#         dates age_layer  se_pay_pv  se_ref  se_ref_kt  se_ref_lk
# 0  2021-04-23       20s       1651      40         25          0
# 1  2021-04-23       30s       2110      55         43          1

# %%
df_ref_none.head(2)
# Out:
#         dates age_layer  se_is_not_target  se_ref  se_ref_kt  se_ref_lk
# 0  2021-04-23       20s               960      46         19          0
# 1  2021-04-23       30s              2255      58         32          0

# %%
df_ref = df_ref_pay.merge(df_ref_none, how = 'inner', on = ['dates', 'age_layer'], copy = False)
df_ref.head(2)
# Out:
#         dates age_layer  se_pay_pv  se_ref_x  se_ref_kt_x  se_ref_lk_x  \
# 0  2021-04-23       20s       1651        40           25            0
# 1  2021-04-23       30s       2110        55           43            1
#
#    se_is_not_target  se_ref_y  se_ref_kt_y  se_ref_lk_y
# 0               960        46           19            0
# 1              2255        58           32            0

# %%
df_ref['01_ref_button'] = df_ref['se_pay_pv'] + df_ref['se_is_not_target']
df_ref['02_ref_page_entered'] = df_ref['se_ref_x'] + df_ref['se_ref_y']
df_ref['03_ref_tried'] = df_ref['se_ref_kt_x'] + df_ref['se_ref_lk_x'] + df_ref['se_ref_kt_y'] + df_ref['se_ref_lk_y']

df_ref
# Out:
#          dates age_layer  se_pay_pv  se_ref_x  se_ref_kt_x  se_ref_lk_x  \
# 0   2021-04-23       20s       1651        40           25            0
# 1   2021-04-23       30s       2110        55           43            1
# 2   2021-04-23       40s       2002        93           79            0
# 3   2021-04-23       50s        388        22           18            0
# 4   2021-04-23       60s        129         9            7            0
# 5   2021-04-23   Unknown          7         0            0            0
# 6   2021-04-24       20s       1766        30           17            0
# 7   2021-04-24       30s       2061        74           52            0
# 8   2021-04-24       40s       1808        60           49            1
# 9   2021-04-24       50s        463        20           16            0
# 10  2021-04-24       60s        129         5            3            0
# 11  2021-04-24   Unknown         12         0            0            0
# 12  2021-04-25       20s       2251        50           34            0
# 13  2021-04-25       30s       2495        89           63            0
# 14  2021-04-25       40s       2762       104           82            0
# 15  2021-04-25       50s        537        23           16            0
# 16  2021-04-25       60s        139         2            1            0
# 17  2021-04-25   Unknown         20         1            0            0
# 18  2021-04-26       20s       2014        64           42            0
# 19  2021-04-26       30s       1893        63           52            0
# 20  2021-04-26       40s       2144        89           70            0
# 21  2021-04-26       50s        577        27           22            0
# 22  2021-04-26       60s        102         6            5            0
# 23  2021-04-26   Unknown         17         1            0            0
# 24  2021-04-27       20s       1222        29           20            0
# 25  2021-04-27       30s       1036        47           38            0
# 26  2021-04-27       40s       1092        52           39            0
# 27  2021-04-27       50s        408        24           20            0
# 28  2021-04-27       60s         76         3            3            0
# 29  2021-04-27   Unknown          5         0            0            0
# 30  2021-04-28       20s        902        27           16            0
# 31  2021-04-28       30s        790        25           17            0
# 32  2021-04-28       40s        802        42           34            0
# 33  2021-04-28       50s        257         9            8            0
# 34  2021-04-28       60s         63         4            4            0
# 35  2021-04-28   Unknown          7         0            0            0
#
#     se_is_not_target  se_ref_y  se_ref_kt_y  se_ref_lk_y  01_ref_button  \
# 0                960        46           19            0           2611
# 1               2255        58           32            0           4365
# 2               3203        68           40            0           5205
# 3                731        34           20            1           1119
# 4                196         4            1            0            325
# 5                 17         0            0            0             24
# 6               1118        49           25            0           2884
# 7               2305        53           25            0           4366
# 8               3067        61           37            0           4875
# 9                837        26           21            0           1300
# 10               219         2            1            0            348
# 11                16         0            0            0             28
# 12              1262        48           22            0           3513
# 13              2663        72           42            0           5158
# 14              4173        78           57            0           6935
# 15               895        30           20            0           1432
# 16               202         6            5            0            341
# 17                32         1            0            0             52
# 18              1231        47           21            0           3245
# 19              1998        44           32            0           3891
# 20              3219        80           52            0           5363
# 21               840        30           23            0           1417
# 22               210         4            3            0            312
# 23                19         0            0            0             36
# 24               738        23           10            0           1960
# 25              1134        32           21            0           2170
# 26              1851        39           23            0           2943
# 27               644        27           21            0           1052
# 28               136         3            1            0            212
# 29                10         1            0            0             15
# 30               693        29           17            0           1595
# 31               869        19            9            0           1659
# 32              1342        35           20            0           2144
# 33               423        17           13            0            680
# 34               109         6            3            0            172
# 35                 8         1            1            0             15
#
#     02_ref_page_entered  03_ref_tried
# 0                    86            44
# 1                   113            76
# 2                   161           119
# 3                    56            39
# 4                    13             8
# 5                     0             0
# 6                    79            42
# 7                   127            77
# 8                   121            87
# 9                    46            37
# 10                    7             4
# 11                    0             0
# 12                   98            56
# 13                  161           105
# 14                  182           139
# 15                   53            36
# 16                    8             6
# 17                    2             0
# 18                  111            63
# 19                  107            84
# 20                  169           122
# 21                   57            45
# 22                   10             8
# 23                    1             0
# 24                   52            30
# 25                   79            59
# 26                   91            62
# 27                   51            41
# 28                    6             4
# 29                    1             0
# 30                   56            33
# 31                   44            26
# 32                   77            54
# 33                   26            21
# 34                   10             7
# 35                    1             1

# %%
df_ref = df_ref[['dates', 'age_layer', '01_ref_button', '02_ref_page_entered', '03_ref_tried']]
df_ref
# Out:
#          dates age_layer  01_ref_button  02_ref_page_entered  03_ref_tried
# 0   2021-04-23       20s           2611                   86            44
# 1   2021-04-23       30s           4365                  113            76
# 2   2021-04-23       40s           5205                  161           119
# 3   2021-04-23       50s           1119                   56            39
# 4   2021-04-23       60s            325                   13             8
# 5   2021-04-23   Unknown             24                    0             0
# 6   2021-04-24       20s           2884                   79            42
# 7   2021-04-24       30s           4366                  127            77
# 8   2021-04-24       40s           4875                  121            87
# 9   2021-04-24       50s           1300                   46            37
# 10  2021-04-24       60s            348                    7             4
# 11  2021-04-24   Unknown             28                    0             0
# 12  2021-04-25       20s           3513                   98            56
# 13  2021-04-25       30s           5158                  161           105
# 14  2021-04-25       40s           6935                  182           139
# 15  2021-04-25       50s           1432                   53            36
# 16  2021-04-25       60s            341                    8             6
# 17  2021-04-25   Unknown             52                    2             0
# 18  2021-04-26       20s           3245                  111            63
# 19  2021-04-26       30s           3891                  107            84
# 20  2021-04-26       40s           5363                  169           122
# 21  2021-04-26       50s           1417                   57            45
# 22  2021-04-26       60s            312                   10             8
# 23  2021-04-26   Unknown             36                    1             0
# 24  2021-04-27       20s           1960                   52            30
# 25  2021-04-27       30s           2170                   79            59
# 26  2021-04-27       40s           2943                   91            62
# 27  2021-04-27       50s           1052                   51            41
# 28  2021-04-27       60s            212                    6             4
# 29  2021-04-27   Unknown             15                    1             0
# 30  2021-04-28       20s           1595                   56            33
# 31  2021-04-28       30s           1659                   44            26
# 32  2021-04-28       40s           2144                   77            54
# 33  2021-04-28       50s            680                   26            21
# 34  2021-04-28       60s            172                   10             7
# 35  2021-04-28   Unknown             15                    1             1

# %%
df_ref.melt(
    id_vars = ['dates', 'age_layer'],
    value_vars = df_ref.columns[2:],
    var_name = 'step',
    value_name = 'cnts',
)
# Out:
#           dates age_layer           step  cnts
# 0    2021-04-23       20s  01_ref_button  2611
# 1    2021-04-23       30s  01_ref_button  4365
# 2    2021-04-23       40s  01_ref_button  5205
# 3    2021-04-23       50s  01_ref_button  1119
# 4    2021-04-23       60s  01_ref_button   325
# ..          ...       ...            ...   ...
# 103  2021-04-28       30s   03_ref_tried    26
# 104  2021-04-28       40s   03_ref_tried    54
# 105  2021-04-28       50s   03_ref_tried    21
# 106  2021-04-28       60s   03_ref_tried     7
# 107  2021-04-28   Unknown   03_ref_tried     1
#
# [108 rows x 4 columns]

# %%
df_ref_raws\
 = df_ref.melt(
    id_vars = ['dates', 'age_layer'],
    value_vars = df_ref.columns[2:],
    var_name = 'step',
    value_name = 'cnts',
).sort_values(by = ['dates', 'age_layer', 'step'], ascending = True, ignore_index = True)

# %%
df_ref_raws
# Out:
#           dates age_layer                 step  cnts
# 0    2021-04-23       20s        01_ref_button  2611
# 1    2021-04-23       20s  02_ref_page_entered    86
# 2    2021-04-23       20s         03_ref_tried    44
# 3    2021-04-23       30s        01_ref_button  4365
# 4    2021-04-23       30s  02_ref_page_entered   113
# ..          ...       ...                  ...   ...
# 103  2021-04-28       60s  02_ref_page_entered    10
# 104  2021-04-28       60s         03_ref_tried     7
# 105  2021-04-28   Unknown        01_ref_button    15
# 106  2021-04-28   Unknown  02_ref_page_entered     1
# 107  2021-04-28   Unknown         03_ref_tried     1
#
# [108 rows x 4 columns]

# %% [markdown]
# ### 3.2.2. total 친구소개

# %%
df_ref_raws.groupby(['step'])['cnts'].agg('sum').reset_index()
# Out:
#                   step   cnts
# 0        01_ref_button  73762
# 1  02_ref_page_entered   2262
# 2         03_ref_tried   1535

# %%
total_df_ref = df_ref_raws.groupby(['step'])['cnts'].agg('sum').reset_index()

# %%
# %%time
# 누적 전환율
total_df_ref['first_value'] = total_df_ref.iloc[0, 1]
total_df_ref['stacked_conversion'] = total_df_ref['cnts']/total_df_ref['first_value']

fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.barplot(
    data = total_df_ref,
    x = 'step',
    y = 'stacked_conversion'
)

plt.show()
# Out:
# CPU times: user 274 ms, sys: 5.81 ms, total: 280 ms
# Wall time: 471 ms

# %%
# %%time
# 직전 전환율
total_df_ref['previous_step'] = total_df_ref['cnts'].shift(1)
total_df_ref['conversion'] = total_df_ref['cnts']/total_df_ref['previous_step']

fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.barplot(
    data = total_df_ref,
    x = 'step',
    y = 'conversion'
)

plt.show()
# Out:
# CPU times: user 262 ms, sys: 941 µs, total: 263 ms
# Wall time: 344 ms

# %% [markdown]
# ### 3.2.2. 친구소개 드릴다운

# %%
# total ref 만들기 직전 df
df_ref_raws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   dates      108 non-null    object
#  1   age_layer  108 non-null    object
#  2   step       108 non-null    object
#  3   cnts       108 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 3.5+ KB

# %%
df_ref_raws_age = df_ref_raws.groupby(['age_layer', 'step'])['cnts'].agg('sum').reset_index()
df_ref_raws_age
# Out:
#    age_layer                 step   cnts
# 0        20s        01_ref_button  15808
# 1        20s  02_ref_page_entered    482
# 2        20s         03_ref_tried    268
# 3        30s        01_ref_button  21609
# 4        30s  02_ref_page_entered    631
# 5        30s         03_ref_tried    427
# 6        40s        01_ref_button  27465
# 7        40s  02_ref_page_entered    801
# 8        40s         03_ref_tried    583
# 9        50s        01_ref_button   7000
# 10       50s  02_ref_page_entered    289
# 11       50s         03_ref_tried    219
# 12       60s        01_ref_button   1710
# 13       60s  02_ref_page_entered     54
# 14       60s         03_ref_tried     37
# 15   Unknown        01_ref_button    170
# 16   Unknown  02_ref_page_entered      5
# 17   Unknown         03_ref_tried      1

# %%
df_ref_raws_age['previous_step'] = np.where(df_ref_raws_age['step'] == '01_ref_button', np.nan, df_ref_raws_age['cnts'].shift(1))
df_ref_raws_age['previous_conversion'] = df_ref_raws_age['cnts']/df_ref_raws_age['previous_step']
df_ref_raws_age
# Out:
#    age_layer                 step   cnts  previous_step  previous_conversion
# 0        20s        01_ref_button  15808            NaN                  NaN
# 1        20s  02_ref_page_entered    482        15808.0             0.030491
# 2        20s         03_ref_tried    268          482.0             0.556017
# 3        30s        01_ref_button  21609            NaN                  NaN
# 4        30s  02_ref_page_entered    631        21609.0             0.029201
# 5        30s         03_ref_tried    427          631.0             0.676704
# 6        40s        01_ref_button  27465            NaN                  NaN
# 7        40s  02_ref_page_entered    801        27465.0             0.029164
# 8        40s         03_ref_tried    583          801.0             0.727840
# 9        50s        01_ref_button   7000            NaN                  NaN
# 10       50s  02_ref_page_entered    289         7000.0             0.041286
# 11       50s         03_ref_tried    219          289.0             0.757785
# 12       60s        01_ref_button   1710            NaN                  NaN
# 13       60s  02_ref_page_entered     54         1710.0             0.031579
# 14       60s         03_ref_tried     37           54.0             0.685185
# 15   Unknown        01_ref_button    170            NaN                  NaN
# 16   Unknown  02_ref_page_entered      5          170.0             0.029412
# 17   Unknown         03_ref_tried      1            5.0             0.200000

# %%
df_ref_raws_age['first_value'] = df_ref_raws_age.groupby(['age_layer'])['cnts'].transform('max')
df_ref_raws_age['stacked_conversion'] = df_ref_raws_age['cnts']/df_ref_raws_age['first_value']
df_ref_raws_age.head(9)
# Out:
#   age_layer                 step   cnts  previous_step  previous_conversion  \
# 0       20s        01_ref_button  15808            NaN                  NaN
# 1       20s  02_ref_page_entered    482        15808.0             0.030491
# 2       20s         03_ref_tried    268          482.0             0.556017
# 3       30s        01_ref_button  21609            NaN                  NaN
# 4       30s  02_ref_page_entered    631        21609.0             0.029201
# 5       30s         03_ref_tried    427          631.0             0.676704
# 6       40s        01_ref_button  27465            NaN                  NaN
# 7       40s  02_ref_page_entered    801        27465.0             0.029164
# 8       40s         03_ref_tried    583          801.0             0.727840
#
#    first_value  stacked_conversion
# 0        15808            1.000000
# 1        15808            0.030491
# 2        15808            0.016953
# 3        21609            1.000000
# 4        21609            0.029201
# 5        21609            0.019760
# 6        27465            1.000000
# 7        27465            0.029164
# 8        27465            0.021227

# %%
df_ref_raws_age.tail(9)
# Out:
#    age_layer                 step  cnts  previous_step  previous_conversion  \
# 9        50s        01_ref_button  7000            NaN                  NaN
# 10       50s  02_ref_page_entered   289         7000.0             0.041286
# 11       50s         03_ref_tried   219          289.0             0.757785
# 12       60s        01_ref_button  1710            NaN                  NaN
# 13       60s  02_ref_page_entered    54         1710.0             0.031579
# 14       60s         03_ref_tried    37           54.0             0.685185
# 15   Unknown        01_ref_button   170            NaN                  NaN
# 16   Unknown  02_ref_page_entered     5          170.0             0.029412
# 17   Unknown         03_ref_tried     1            5.0             0.200000
#
#     first_value  stacked_conversion
# 9          7000            1.000000
# 10         7000            0.041286
# 11         7000            0.031286
# 12         1710            1.000000
# 13         1710            0.031579
# 14         1710            0.021637
# 15          170            1.000000
# 16          170            0.029412
# 17          170            0.005882

# %%
# %%time
# 누적전환율
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.lineplot(
    data = df_ref_raws_age,
    x = 'step',
    y = 'stacked_conversion',
    hue = 'age_layer',
    marker = 'o'
)

plt.show()
# Out:
# CPU times: user 391 ms, sys: 9.44 ms, total: 401 ms
# Wall time: 541 ms

# %%
# %%time
# 직전전환율
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.lineplot(
    data = df_ref_raws_age,
    x = 'step',
    y = 'previous_conversion',
    hue = 'age_layer',
    marker = 'o'
)

plt.show()
# Out:
# CPU times: user 420 ms, sys: 13 ms, total: 433 ms
# Wall time: 640 ms

# %% [markdown]
# # _4. 체류시간

# %% [markdown]
# ## 4.1. 라이브러리 불러오기 및 data type 변경

# %%
# date 관련 library
from datetime import *

# %%
df_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1902435 entries, 0 to 1902434
# Data columns (total 34 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   dates                  object
#  1   hours                  int64
#  2   age_layer              object
#  3   se_inflowed            int64
#  4   se_joined              float64
#  5   se_cert_pv             float64
#  6   se_cert_done           float64
#  7   se_tax_calculation     float64
#  8   se_tax_check           float64
#  9   se_pay_pv              float64
#  10  se_is_not_target       float64
#  11  se_ref                 float64
#  12  se_ref_kt              float64
#  13  se_ref_lk              float64
#  14  se_additional_info_pv  float64
#  15  se_add_done            float64
#  16  se_edit_done           float64
#  17  se_save_done           float64
#  18  et_inflowed            object
#  19  et_joined              object
#  20  et_cert_pv             object
#  21  et_cert_done           object
#  22  et_tax_calculation     object
#  23  et_tax_check           object
#  24  et_pay_pv              object
#  25  et_is_not_target       object
#  26  et_ref                 object
#  27  et_ref_kt              object
#  28  et_ref_lk              object
#  29  et_additional_info_pv  object
#  30  et_add_done            object
#  31  et_edit_done           object
#  32  et_save_done           object
#  33  basic                  int64
# dtypes: float64(14), int64(3), object(17)
# memory usage: 493.5+ MB

# %% [markdown]
# 다음 단계로 진입한 회원만 시간이 잡히므로,
# 이탈 한 사람들은 얼마나 머물렀는 지 모른다
#
# 다만 화면 체류시간 분포를 가늠하면서
# 어떠한 이슈가 있는 지 추정해보고 가설세워 AB테스트로 검증하는 작업 반복

# %%
category
# Out:
# ['dates', 'hours', 'age_layer']

# %%
df_base.columns[18:32+1].tolist()
# Out:
# ['et_inflowed',
#  'et_joined',
#  'et_cert_pv',
#  'et_cert_done',
#  'et_tax_calculation',
#  'et_tax_check',
#  'et_pay_pv',
#  'et_is_not_target',
#  'et_ref',
#  'et_ref_kt',
#  'et_ref_lk',
#  'et_additional_info_pv',
#  'et_add_done',
#  'et_edit_done',
#  'et_save_done']

# %%
category_v1 = category.copy()
for i in df_base.columns[18:32+1].tolist():
    category_v1.append(i)
    print(category_v1)
# Out:
# ['dates', 'hours', 'age_layer', 'et_inflowed']
# ['dates', 'hours', 'age_layer', 'et_inflowed', 'et_joined']
# ['dates', 'hours', 'age_layer', 'et_inflowed', 'et_joined', 'et_cert_pv']
# ['dates', 'hours', 'age_layer', 'et_inflowed', 'et_joined', 'et_cert_pv', 'et_cert_done']
# ['dates', 'hours', 'age_layer', 'et_inflowed', 'et_joined', 'et_cert_pv', 'et_cert_done', 'et_tax_calculation']
# ['dates', 'hours', 'age_layer', 'et_inflowed', 'et_joined', 'et_cert_pv', 'et_cert_done', 'et_tax_calculation', 'et_tax_check']
# ['dates', 'hours', 'age_layer', 'et_inflowed', 'et_joined', 'et_cert_pv', 'et_cert_done', 'et_tax_calculation', 'et_tax_check', 'et_pay_pv']
# ['dates', 'hours', 'age_layer', 'et_inflowed', 'et_joined', 'et_cert_pv', 'et_cert_done', 'et_tax_calculation', 'et_tax_check', 'et_pay_pv', 'et_is_not_target']
# ['dates', 'hours', 'age_layer', 'et_inflowed', 'et_joined', 'et_cert_pv', 'et_cert_done', 'et_tax_calculation', 'et_tax_check', 'et_pay_pv', 'et_is_not_target', 'et_ref']
# ['dates', 'hours', 'age_layer', 'et_inflowed', 'et_joined', 'et_cert_pv', 'et_cert_done', 'et_tax_calculation', 'et_tax_check', 'et_pay_pv', 'et_is_not_target', 'et_ref', 'et_ref_kt']
# ['dates', 'hours', 'age_layer', 'et_inflowed', 'et_joined', 'et_cert_pv', 'et_cert_done', 'et_tax_calculation', 'et_tax_check', 'et_pay_pv', 'et_is_not_target', 'et_ref', 'et_ref_kt', 'et_ref_lk']
# ['dates', 'hours', 'age_layer', 'et_inflowed', 'et_joined', 'et_cert_pv', 'et_cert_done', 'et_tax_calculation', 'et_tax_check', 'et_pay_pv', 'et_is_not_target', 'et_ref', 'et_ref_kt', 'et_ref_lk', 'et_additional_info_pv']
# ['dates', 'hours', 'age_layer', 'et_inflowed', 'et_joined', 'et_cert_pv', 'et_cert_done', 'et_tax_calculation', 'et_tax_check', 'et_pay_pv', 'et_is_not_target', 'et_ref', 'et_ref_kt', 'et_ref_lk', 'et_additional_info_pv', 'et_add_done']
# ['dates', 'hours', 'age_layer', 'et_inflowed', 'et_joined', 'et_cert_pv', 'et_cert_done', 'et_tax_calculation', 'et_tax_check', 'et_pay_pv', 'et_is_not_target', 'et_ref', 'et_ref_kt', 'et_ref_lk', 'et_additional_info_pv', 'et_add_done', 'et_edit_done']
# ['dates', 'hours', 'age_layer', 'et_inflowed', 'et_joined', 'et_cert_pv', 'et_cert_done', 'et_tax_calculation', 'et_tax_check', 'et_pay_pv', 'et_is_not_target', 'et_ref', 'et_ref_kt', 'et_ref_lk', 'et_additional_info_pv', 'et_add_done', 'et_edit_done', 'et_save_done']

# %%
df_et = df_base[category_v1]
df_et.head()
# Out:
#         dates  hours age_layer              et_inflowed et_joined et_cert_pv  \
# 0  2021-04-29      1   Unknown  2021-04-29 01:41:19.016       NaN        NaN
# 1  2021-04-29      4   Unknown  2021-04-29 04:51:10.978       NaN        NaN
# 2  2021-04-29      3   Unknown  2021-04-29 03:57:55.571       NaN        NaN
# 3  2021-04-28     10   Unknown  2021-04-28 10:00:51.887       NaN        NaN
# 4  2021-04-28     21   Unknown  2021-04-28 21:38:14.822       NaN        NaN
#
#   et_cert_done et_tax_calculation et_tax_check et_pay_pv et_is_not_target  \
# 0          NaN                NaN          NaN       NaN              NaN
# 1          NaN                NaN          NaN       NaN              NaN
# 2          NaN                NaN          NaN       NaN              NaN
# 3          NaN                NaN          NaN       NaN              NaN
# 4          NaN                NaN          NaN       NaN              NaN
#
#   et_ref et_ref_kt et_ref_lk et_additional_info_pv et_add_done et_edit_done  \
# 0    NaN       NaN       NaN                   NaN         NaN          NaN
# 1    NaN       NaN       NaN                   NaN         NaN          NaN
# 2    NaN       NaN       NaN                   NaN         NaN          NaN
# 3    NaN       NaN       NaN                   NaN         NaN          NaN
# 4    NaN       NaN       NaN                   NaN         NaN          NaN
#
#   et_save_done
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df_et.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1902435 entries, 0 to 1902434
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   dates                  object
#  1   hours                  int64
#  2   age_layer              object
#  3   et_inflowed            object
#  4   et_joined              object
#  5   et_cert_pv             object
#  6   et_cert_done           object
#  7   et_tax_calculation     object
#  8   et_tax_check           object
#  9   et_pay_pv              object
#  10  et_is_not_target       object
#  11  et_ref                 object
#  12  et_ref_kt              object
#  13  et_ref_lk              object
#  14  et_additional_info_pv  object
#  15  et_add_done            object
#  16  et_edit_done           object
#  17  et_save_done           object
# dtypes: int64(1), object(17)
# memory usage: 261.3+ MB

# %%
# %%time
for temp_et in df_et.columns[3:]:
    df_et[temp_et] = pd.to_datetime(df_et[temp_et])

df_et.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1902435 entries, 0 to 1902434
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   dates                  object
#  1   hours                  int64
#  2   age_layer              object
#  3   et_inflowed            datetime64[ns]
#  4   et_joined              datetime64[ns]
#  5   et_cert_pv             datetime64[ns]
#  6   et_cert_done           datetime64[ns]
#  7   et_tax_calculation     datetime64[ns]
#  8   et_tax_check           datetime64[ns]
#  9   et_pay_pv              datetime64[ns]
#  10  et_is_not_target       datetime64[ns]
#  11  et_ref                 datetime64[ns]
#  12  et_ref_kt              datetime64[ns]
#  13  et_ref_lk              datetime64[ns]
#  14  et_additional_info_pv  datetime64[ns]
#  15  et_add_done            datetime64[ns]
#  16  et_edit_done           datetime64[ns]
#  17  et_save_done           datetime64[ns]
# dtypes: datetime64[ns](15), int64(1), object(2)
# memory usage: 261.3+ MB
# CPU times: user 1.02 s, sys: 27.7 ms, total: 1.05 s
# Wall time: 1.1 s

# %% [markdown]
# ## 4.2. 체류시간 산출

# %%
# %%time
# df_et['stay_inflowed'] = (df_et['et_joined'] - df_et['et_inflowed']).astype('timedelta64[s]')
df_et['stay_inflowed'] = (df_et['et_joined'] - df_et['et_inflowed']).astype('timedelta64[ms]')/1000
# Out:
# CPU times: user 74.1 ms, sys: 7.92 ms, total: 82.1 ms
# Wall time: 79.4 ms

# %%
df_et[['et_inflowed', 'et_joined', 'stay_inflowed']].sample(5)
# Out:
#                     et_inflowed               et_joined  stay_inflowed
# 786786  2021-04-26 19:10:00.713                     NaT            NaN
# 1468508 2021-04-25 17:17:21.732                     NaT            NaN
# 1085024 2021-04-24 13:14:54.502 2021-04-24 13:14:59.563          5.061
# 368109  2021-04-27 13:13:39.088 2021-04-27 13:13:44.869          5.781
# 398275  2021-04-24 20:17:20.969                     NaT            NaN

# %%
df_et['stay_joined'] = (df_et['et_cert_pv'] - df_et['et_joined']).astype('timedelta64[ms]')/1000
df_et['stay_cert'] = (df_et['et_cert_done'] - df_et['et_cert_pv']).astype('timedelta64[ms]')/1000

# %%
df_et[['dates', 'hours', 'age_layer', 'stay_inflowed', 'stay_joined', 'stay_cert']].sample(5)
# Out:
#               dates  hours age_layer  stay_inflowed  stay_joined  stay_cert
# 495894   2021-04-27     14   Unknown            NaN          NaN        NaN
# 1645190  2021-04-23     14   Unknown            NaN          NaN        NaN
# 953179   2021-04-23     22   Unknown          6.633          NaN        NaN
# 443341   2021-04-27     18   Unknown          5.840          NaN        NaN
# 1432420  2021-04-25     19   Unknown            NaN          NaN        NaN

# %%
df_stay = df_et[['dates', 'hours', 'age_layer', 'stay_inflowed', 'stay_joined', 'stay_cert']]
df_stay.head()
# Out:
#         dates  hours age_layer  stay_inflowed  stay_joined  stay_cert
# 0  2021-04-29      1   Unknown            NaN          NaN        NaN
# 1  2021-04-29      4   Unknown            NaN          NaN        NaN
# 2  2021-04-29      3   Unknown            NaN          NaN        NaN
# 3  2021-04-28     10   Unknown            NaN          NaN        NaN
# 4  2021-04-28     21   Unknown            NaN          NaN        NaN

# %%
df_stay.sample(10)
# Out:
#               dates  hours age_layer  stay_inflowed  stay_joined  stay_cert
# 178175   2021-04-27      9   Unknown            NaN          NaN        NaN
# 1879020  2021-04-26     15       50s         15.863       14.719    107.850
# 1030241  2021-04-24      9   Unknown            NaN          NaN        NaN
# 263948   2021-04-26     23   Unknown            NaN          NaN        NaN
# 1379281  2021-04-27     17   Unknown            NaN          NaN        NaN
# 1566545  2021-04-26     12   Unknown            NaN          NaN        NaN
# 1685759  2021-04-24     20   Unknown            NaN          NaN        NaN
# 1890849  2021-04-24      5   Unknown          9.648          NaN        NaN
# 1221429  2021-04-23     16       20s         11.382       25.045     45.013
# 1161659  2021-04-25      2       30s          6.536          NaN        NaN

# %%
df_stay_inflowed = df_stay[df_stay['stay_inflowed'].notnull()]
df_stay_inflowed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600316 entries, 10 to 1902434
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   dates          600316 non-null  object
#  1   hours          600316 non-null  int64
#  2   age_layer      600316 non-null  object
#  3   stay_inflowed  600316 non-null  float64
#  4   stay_joined    306358 non-null  float64
#  5   stay_cert      181986 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 32.1+ MB

# %% [markdown]
# ## 4.3. 체류 시간 분포 확인

# %% [markdown]
# ### 4.3.1. 유입 화면

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.distplot(df_stay_inflowed['stay_inflowed'], hist = False)

plt.show()
# Out:
# CPU times: user 2.77 s, sys: 229 ms, total: 3 s
# Wall time: 2.88 s

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.distplot(np.log10(df_stay_inflowed['stay_inflowed']), hist = False)

plt.show()
# Out:
# CPU times: user 3.23 s, sys: 142 ms, total: 3.37 s
# Wall time: 3.24 s

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.distplot(np.log10(df_stay_inflowed['stay_inflowed']), hist = True)

plt.show()
# Out:
# CPU times: user 3.18 s, sys: 60.5 ms, total: 3.24 s
# Wall time: 3.23 s

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.distplot(np.log10(df_stay_inflowed['stay_inflowed']), hist = True)
plt.axvline(np.log10(5), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(10), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(15), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.show()
# Out:
# CPU times: user 3.28 s, sys: 227 ms, total: 3.5 s
# Wall time: 3.25 s

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '20s']['stay_inflowed']), hist = True, label = '20s')
sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '30s']['stay_inflowed']), hist = True, label = '30s')
sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '40s']['stay_inflowed']), hist = True, label = '40s')
sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '50s']['stay_inflowed']), hist = True, label = '50s')


plt.axvline(np.log10(5), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(10), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(15), color = 'darkred', linestyle = '--', linewidth = 0.5)

plt.legend()
plt.show()
# Out:
# CPU times: user 2.61 s, sys: 561 ms, total: 3.17 s
# Wall time: 2.56 s

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '20s']['stay_inflowed']), hist = False, label = '20s')
sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '30s']['stay_inflowed']), hist = False, label = '30s')
sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '40s']['stay_inflowed']), hist = False, label = '40s')
sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '50s']['stay_inflowed']), hist = False, label = '50s')


plt.axvline(np.log10(5), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(10), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(15), color = 'darkred', linestyle = '--', linewidth = 0.5)

plt.legend()
plt.show()
# Out:
# CPU times: user 2.23 s, sys: 566 ms, total: 2.8 s
# Wall time: 2.2 s

# %% [markdown]
# #### 유입화면 체류시간 trend

# %%
df_stay_inflowed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600316 entries, 10 to 1902434
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   dates          600316 non-null  object
#  1   hours          600316 non-null  int64
#  2   age_layer      600316 non-null  object
#  3   stay_inflowed  600316 non-null  float64
#  4   stay_joined    306358 non-null  float64
#  5   stay_cert      181986 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 32.1+ MB

# %%
df_stay_inflowed.groupby(['dates'])['stay_inflowed'].agg('mean').reset_index()
# Out:
#         dates  stay_inflowed
# 0  2021-04-23      17.227283
# 1  2021-04-24      18.698384
# 2  2021-04-25      18.569290
# 3  2021-04-26      18.165601
# 4  2021-04-27      25.727941
# 5  2021-04-28      20.442823
# 6  2021-04-29      26.626346

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))
sns.lineplot(
    data = df_stay_inflowed.groupby(['dates'])['stay_inflowed'].agg('mean').reset_index(),
    x = 'dates',
    y = 'stay_inflowed',
    marker = 'o'
)

plt.show()

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))
sns.lineplot(
    data = df_stay_inflowed.groupby(['dates', 'age_layer'])['stay_inflowed'].agg('mean').reset_index(),
    x = 'dates',
    y = 'stay_inflowed',
    hue = 'age_layer',
    marker = 'o'
)

plt.show()

# %% [markdown]
# ### 4.3.2. 가입 화면

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.distplot(df_stay_inflowed['stay_joined'], hist = False)

plt.show()
# Out:
# CPU times: user 1.58 s, sys: 147 ms, total: 1.72 s
# Wall time: 1.6 s

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.distplot(np.log10(df_stay_inflowed['stay_joined']), hist = False)

plt.show()
# Out:
# CPU times: user 1.86 s, sys: 133 ms, total: 2 s
# Wall time: 1.88 s

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.distplot(np.log10(df_stay_inflowed['stay_joined']), hist = False)


plt.axvline(np.log10(5), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(10), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(15), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.show()
# Out:
# CPU times: user 1.79 s, sys: 229 ms, total: 2.02 s
# Wall time: 1.77 s

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '20s']['stay_joined']), hist = False, label = '20s')
sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '30s']['stay_joined']), hist = False, label = '30s')
sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '40s']['stay_joined']), hist = False, label = '40s')
sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '50s']['stay_joined']), hist = False, label = '50s')
sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '60s']['stay_joined']), hist = False, label = '60s')


plt.axvline(np.log10(5), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(10), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(15), color = 'darkred', linestyle = '--', linewidth = 0.5)

plt.legend()
plt.show()
# Out:
# CPU times: user 1.89 s, sys: 546 ms, total: 2.44 s
# Wall time: 1.84 s

# %% [markdown]
# #### 가입화면 체류시간 trend

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))
sns.lineplot(
    data = df_stay_inflowed.groupby(['dates'])['stay_joined'].agg('mean').reset_index(),
    x = 'dates',
    y = 'stay_joined',
    marker = 'o'
)

plt.show()

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))
sns.lineplot(
    data = df_stay_inflowed.groupby(['dates', 'age_layer'])['stay_joined'].agg('mean').reset_index(),
    x = 'dates',
    y = 'stay_joined',
    hue = 'age_layer',
    marker = 'o'
)

plt.show()

# %% [markdown]
# ### 4.3.3. 인증화면

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.distplot(df_stay_inflowed['stay_cert'], hist = False)

plt.show()
# Out:
# CPU times: user 1.06 s, sys: 129 ms, total: 1.19 s
# Wall time: 1.07 s

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.distplot(np.log10(df_stay_inflowed['stay_cert']), hist = False)

plt.show()
# Out:
# CPU times: user 1.22 s, sys: 133 ms, total: 1.36 s
# Wall time: 1.23 s

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.distplot(np.log10(df_stay_inflowed['stay_cert']), hist = False)

plt.axvline(np.log10(5), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(10), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(60), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(100), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(300), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.show()
# Out:
# CPU times: user 1.27 s, sys: 202 ms, total: 1.47 s
# Wall time: 1.27 s

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.distplot(np.log10(df_stay_inflowed['stay_cert']), hist = False)

plt.axvline(np.log10(20), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(40), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(60), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(120), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(300), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.show()
# Out:
# CPU times: user 1.29 s, sys: 223 ms, total: 1.51 s
# Wall time: 1.27 s

# %%
# %%time
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))

sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '20s']['stay_cert']), hist = False, label = '20s')
sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '30s']['stay_cert']), hist = False, label = '30s')
sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '40s']['stay_cert']), hist = False, label = '40s')
sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '50s']['stay_cert']), hist = False, label = '50s')
sns.distplot(np.log10(df_stay_inflowed[df_stay_inflowed['age_layer'] == '60s']['stay_cert']), hist = False, label = '60s')

plt.axvline(np.log10(20), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(40), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(60), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(120), color = 'darkred', linestyle = '--', linewidth = 0.5)
plt.axvline(np.log10(300), color = 'darkred', linestyle = '--', linewidth = 0.5)

plt.legend()
plt.show()
# Out:
# CPU times: user 1.78 s, sys: 526 ms, total: 2.31 s
# Wall time: 1.75 s

# %% [markdown]
# #### 인증화면 체류시간 trend

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))
sns.lineplot(
    data = df_stay_inflowed.groupby(['dates'])['stay_cert'].agg('mean').reset_index(),
    x = 'dates',
    y = 'stay_cert',
    marker = 'o'
)

plt.show()

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (24, 6))
sns.lineplot(
    data = df_stay_inflowed.groupby(['dates', 'age_layer'])['stay_cert'].agg('mean').reset_index(),
    x = 'dates',
    y = 'stay_cert',
    hue = 'age_layer',
    marker = 'o'
)

plt.show()
